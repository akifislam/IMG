# %% [markdown]
# # 1(b)
# #### Take grayscale image of size 512x512 and perform the following operations -
# Decrease it intensity level resolution by one bit up to reach its binary format observe its change when displaying in the same window size
#
# ###### Akif Islam <br> Department of CSE-RU <br> iamakifislam@gmail.com <br> 5th September 2023

# %%
import cv2
import numpy as np

img = cv2.imread("Mini.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img = cv2.resize(img,(512,512))

import matplotlib.pyplot as plt 
plt.imshow(img,cmap="gray")
plt.show()

# %%
img.shape
# Out:
# (512, 512)

# %% [markdown]
# # Normalization

# %%
img = img/255
img
# Out:
# array([[0.47058824, 0.47058824, 0.4627451 , ..., 0.30588235, 0.2627451 ,
#         0.25882353],
#        [0.45490196, 0.4745098 , 0.4627451 , ..., 0.28235294, 0.2627451 ,
#         0.25490196],
#        [0.4627451 , 0.47058824, 0.47058824, ..., 0.2745098 , 0.25882353,
#         0.25490196],
#        ...,
#        [0.51764706, 0.49019608, 0.52156863, ..., 0.46666667, 0.38039216,
#         0.34509804],
#        [0.54117647, 0.49019608, 0.53333333, ..., 0.40784314, 0.34509804,
#         0.30196078],
#        [0.5254902 , 0.52156863, 0.52941176, ..., 0.35294118, 0.29019608,
#         0.28627451]])

# %% [markdown]
# # Subplots

# %%
plt.figure(figsize=(6,15))


for i in range(8,0,-1):
    plt.subplot(4,2,i)
    plt.title(f"{i} Bit")
    new_image = np.floor(img*(2**i))
    plt.imshow(new_image,cmap='gray')

plt.show()
